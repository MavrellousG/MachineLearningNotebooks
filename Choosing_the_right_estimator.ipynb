# %% [markdown]
# <a href="https://colab.research.google.com/github/MavrellousG/MachineLearningNotebooks/blob/master/Choosing_the_right_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Machine Learning
# ### Project: Model Selection

# %% [markdown]
# # Part 1: Business and Data Understanding

# %% [markdown]
# ### Q. Define the problem domain

# %% [markdown]
# ### Q. Identify candidate questions for your machine learning project

# %% [markdown]
# ### Q. Identify a suitable dataset for your canditate question(s)

# %% [markdown]
# Go have a look at any of these websites:
#
# * https://www.kaggle.com/datasets
# * https://datasetsearch.research.google.com/
# * https://data.gov.uk/
#
# Find an interesting looking data set related to your problem domain and get a copy of it

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/diabetes.csv', header=0)
data.tail(10)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 758            1      106  ...   26        0
# 759            6      190  ...   66        1
# 760            2       88  ...   22        0
# 761            9      170  ...   43        1
# 762            9       89  ...   33        0
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [10 rows x 9 columns]

# %%
for col_name in data.columns:
  unique_values = data[col_name].value_counts()#unique_value_counter
  unique_values_counted = unique_values.count()
  print(col_name + ' : ' + str(unique_values_counted) )
# Out:
# Pregnancies : 17
# Glucose : 136
# BloodPressure : 47
# SkinThickness : 51
# Insulin : 186
# BMI : 248
# DiabetesPedigreeFunction : 517
# Age : 52
# Outcome : 2

# %%
all_correlations = data.corr()
all_correlations
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.129459  ...  0.544341  0.221898
# Glucose                      0.129459  1.000000  ...  0.263514  0.466581
# BloodPressure                0.141282  0.152590  ...  0.239528  0.065068
# SkinThickness               -0.081672  0.057328  ... -0.113970  0.074752
# Insulin                     -0.073535  0.331357  ... -0.042163  0.130548
# BMI                          0.017683  0.221071  ...  0.036242  0.292695
# DiabetesPedigreeFunction    -0.033523  0.137337  ...  0.033561  0.173844
# Age                          0.544341  0.263514  ...  1.000000  0.238356
# Outcome                      0.221898  0.466581  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure()
sns.heatmap(all_correlations, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Q. Generate a descriptive statistics report for the columns in your dataset

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
data.describe().T
# Out:
#                           count        mean  ...        75%     max
# Pregnancies               768.0    3.845052  ...    6.00000   17.00
# Glucose                   768.0  120.894531  ...  140.25000  199.00
# BloodPressure             768.0   69.105469  ...   80.00000  122.00
# SkinThickness             768.0   20.536458  ...   32.00000   99.00
# Insulin                   768.0   79.799479  ...  127.25000  846.00
# BMI                       768.0   31.992578  ...   36.60000   67.10
# DiabetesPedigreeFunction  768.0    0.471876  ...    0.62625    2.42
# Age                       768.0   33.240885  ...   41.00000   81.00
# Outcome                   768.0    0.348958  ...    1.00000    1.00
#
# [9 rows x 8 columns]

# %% [markdown]
# # Part 2: Data Preparation

# %% [markdown]
# ### Q. Discuss the following types of missing data and how they would be handled in reference to your dataset where applicable.
# *	Missing completely at random (MCAR)
# *	Missing at random (MAR)
# *	Missing Not at Random (MNAR)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#We do not have any missing values.

# %% [markdown]
# # Part 3: Model Selection

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51596dce-313b-4757-a11d-750e2a1bb048" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51596dce-313b-4757-a11d-750e2a1bb048">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Best Model Summary.JPG to Best Model Summary (1).JPG
# Saving Configuration settings.JPG to Configuration settings (1).JPG
# Saving Cumulative gains curve.JPG to Cumulative gains curve (1).JPG
# Saving Lift curve.JPG to Lift curve (1).JPG
# Saving Model Metrics.JPG to Model Metrics (1).JPG
# Saving precision recall.JPG to precision recall (1).JPG
# Saving ROC Faulse positive rate.JPG to ROC Faulse positive rate (1).JPG

# %%
Image('/content/Best Model Summary.JPG')

# %% [markdown]
# ### Q. Use the cheat sheet below to choose the algorithm/estimator suitable for building a model to address your candidate question(s)
#
# * https://scikit-learn.org/stable/tutorial/machine_learning_map/

# %%
Image('/content/Configuration settings.JPG')

# %% [markdown]
# # Part 4: Model Evaluation

# %% [markdown]
# ### Q. Identify which of the statistical measures below are suitable for the evaluation of your model.
#
# Classification Metrics:
# * Accuracy
# * Precision
# * Recall
# * F1 Score
#
# Regression Metrics:
#
# * Mean absolute error (MAE)
# * Root mean squared error (RMSE)
# * Relative absolute error (RAE)
# * Relative squared error (RSE)
# * Mean Zero One Error (MZOE)
# * Coefficient of determination

# %%
Image('/content/Model Metrics.JPG')

# %%
Image('/content/Cumulative gains curve.JPG')

# %%
Image('/content/Lift curve.JPG')

# %%
Image('/content/ROC Faulse positive rate.JPG')

# %%
Image('/content/precision recall.JPG')

# %% [markdown]
# # Part 5: Stretch - Model Deployment

# %% [markdown]
# ### Q. Evaluate the open-source app framework for Machine Learning model deployment below in your own time.
#
# * https://streamlit.io/

# %%
import urllib.request
import json
import os
import ssl

def allowSelfSignedHttps(allowed):
    # bypass the server certificate verification on client side
    if allowed and not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None):
        ssl._create_default_https_context = ssl._create_unverified_context

allowSelfSignedHttps(True) # this line is needed if you use self-signed certificate in your scoring service.

# Request data goes here
data = {
    "Inputs": {
        "WebServiceInput0":
        [
            {
                'PatientID': "1882185",
                'Pregnancies': "9",
                'PlasmaGlucose': "104",
                'DiastolicBloodPressure': "51",
                'TricepsThickness': "7",
                'SerumInsulin': "24",
                'BMI': "27.36983156",
                'DiabetesPedigree': "1.3504720469999998",
                'Age': "43",
            },
        ],
    },
    "GlobalParameters": {
    }
}

body = str.encode(json.dumps(data))

url = 'http://a9c5017c-b4fd-48b0-b443-a3497c6a53f9.eastus2.azurecontainer.io/score'
api_key = 'BgX544fTHVEV4BXDMcJzclDSoyysyXca' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
b'{"Results": {"WebServiceOutput0": [{"PatientID": 1882185.0, "DiabetesPrediction": 1.0, "Probability": 0.7034111544417705}]}}'
# Out:
# b'{"Results": {"WebServiceOutput0": [{"PatientID": 1882185.0, "DiabetesPrediction": 1.0, "Probability": 0.7034111544417705}]}}'
# b'{"Results": {"WebServiceOutput0": [{"PatientID": 1882185.0, "DiabetesPrediction": 1.0, "Probability": 0.7034111544417705}]}}'
